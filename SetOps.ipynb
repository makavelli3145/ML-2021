# %%
class Operation():
    
    def __init__(self, input_nodes = []):
        
        #We are initializing some operation
        self.input_nodes = input_nodes
        self.output_nodes = []
        
        #Every Operation has input nodes and output nodes
        
        for node in input_nodes:            #??
            node.output_nodes.append(self)  #??This will form a list of all the 
                                            #  inputs that will be computed at a node
            
            #Set as a default graph
            
    def compute(self):
        
        #This will be overidden 
        pass

# %% [markdown]
# ## Now lets create our operation classes

# %%
class Add(Operation):
    
    def __init__(self, x, y):
        
        super().__init__([x, y])
    
    #Now we overide compute
    def compute(self, x_var, y_var):
        
        self.inputs = [x_var, y_var]
        
        #return the sum of our inputs
        return x_var + y_var
