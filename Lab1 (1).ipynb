# %%
# Initialisation Cell
from matplotlib import pyplot as plt
from IPython.display import display, HTML, Javascript
from math import *
import seaborn as sns
import pandas as pd
import numpy as np
import numpy.testing as nt

# %% [markdown]
# # Optimisation II - Lab 1
#
#
# ## Instructions
#
# * Read all the instructions carefully.
# * **Numpy** has a help file for every function if you get stuck. See: https://docs.scipy.org/doc/numpy-1.14.5/reference/
# * See these useful links:
#     * https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html
#     * https://docs.scipy.org/doc/numpy/user/quickstart.html
# * **Numpy** is not always required.
# * There are also numerous sources available on the internet, Google is your friend!

# %% [markdown]
# ## Warm-up Exercises
#
# Complete the following warm-up tasks:
# ### Question 1
#
# Write a function that will convert a decimal number to a binary number. The function must be able to handle a decimal of any length.

# %%
def dec_to_bin(n):
    """
    Inputs
        n: a scalar real value
    
    Output
        s: a binary string equal to n
    """
    # YOUR CODE HERE
    
    if n==0:
        return '0'
    s = ''
    while (n>0):
        if n%2== 0:
            s = '0' +s
        else:
            s = '1'+ s
            
        n//=2
                
    return s
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
nt.assert_string_equal('1101', dec_to_bin(13))
print('All Tests Passed!!!')
# Out:
# All Tests Passed!!!

# %% [markdown]
# ### Question 2
#
# A string is simply an ordered collection of symbols selected from some alphabet and formed into a word; the length of a string is the number of symbols that it contains. An example of a length 21 DNA string (whose alphabet contains the symbols 'A', 'C', 'G', and 'T') is "ATGCTTCAGAAAGGTCTTACG." Write a function that takes as input, a vector  $s$  and returns a vector of four integers counting the respective number of times that the symbols 'A', 'C', 'G', and 'T' occur in  $s$.

# %%
def dna(s):
    """
    Inputs
    s: a string of DNA sequence
    
    Outputs
    occ_seq: a list of the number of times A, C, G and T occur (in this order)
    """
    # YOUR CODE HERE
    m = []

    a = 0
    b = 0
    c = 0
    d = 0
    
    for i in range(len(s)):
        if s[i] == 'A':
            a = a + 1
        else:
                a = a + 0
        if s[i] == 'C':
            b = b + 1
        else:
                b =b + 0
        if s[i] == 'G':
            c = c + 1
        else:
                c = c + 0
        if s[i] == 'T':
            d = d + 1
        else:
                d = d + 0
       
    m.append(a)
    m.append(b)
    m.append(c)
    m.append(d)
    
    
    return m
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
s = 'ATGCTTCAGAAAGGTCTTACG'
nt.assert_array_equal([6, 4, 5, 6], dna(s), err_msg='incorrect function')
print('All Tests Passed!!!')
# Out:
# All Tests Passed!!!

# %% [markdown]
# ## Question 2.2
# #### Write a breadth first search that finds all subsets of a number which is in binary(Refer to the "
# #### Tech with Tim" YouTube tutorial)

# %% [markdown]
# ### Question 3
#
# Write a function that takes a matrix  $M$  as input and returns a matrix that contains only those elements of  $M$  that are in odd rows and columns.

# %%
def matrix_extraction(M):
    """
    Inputs:
        M: a random numpy matrix
    
    Outputs:
        N: a matrix with the odd rows and columns of M only
    """
    
    return M[::2,::2]
        
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
M = np.array([[0.29977941, 0.05186872, 0.57587171, 0.56806655, 0.38424249],
             [0.25568574, 0.53849314, 0.76387274, 0.29669909, 0.68029403],
             [0.9338883,  0.44839289, 0.48052527, 0.60921226, 0.89123473],
             [0.76114271, 0.61475746, 0.04465618, 0.85599524, 0.29450567],
             [0.43419249, 0.04936524, 0.14366823, 0.30798834, 0.91016638]])
N = np.array([[0.29977941, 0.57587171, 0.38424249],
             [0.9338883,  0.48052527, 0.89123473],
             [0.43419249, 0.14366823, 0.91016638]])
nt.assert_array_almost_equal(N, matrix_extraction(M), err_msg='incorrect function')
print('All Tests Passed!!!')
# Out:
# All Tests Passed!!!

# %% [markdown]
# ### Question 4
#
# Write a function that computes how much money we have. It takes a single input argument, a row vector  $c$, whose elements specify the number of five cent, 10 cent, 20 cent and 50 cent coins we have (in the order listed here). The output should be a scalar value of the total in Rands - not cents.

# %%
def rand_compute(c):
    """
    Inputs
        c: a list of the number of 5, 10, 20 and 50 cent coins
        
    Outputs
        total: the scalar Rand value of all the coins in the list
    """
    # YOUR CODE HERE
    
    sum = (c[0] * 5) + (c[1] * 10) + (c[2] * 20) + (c[3] * 50)
    return sum/100
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
c = [0,1,0,2]
nt.assert_equal(1.1, rand_compute(c), err_msg= 'incorrect function')
print('All Tests Passed!!!')
# Out:
# All Tests Passed!!!

# %% [markdown]
# ## Main Exercises
#
# ### Question 1
#
# Write a function which randomly samples a local neighbourhood. This neighbourhood maybe circular or square in nature. The function takes as input, a vector of (x, y) coordinate points, i.e. $[x, y]$. A scalar, $r$, a radial value, a scalar, $n$, the number of samples and scalar, $s$, the shape to explore ($s = 1$ - a circular radius and $s =2$ a square neighbourhood). The function should return array containing the coordinates of the randomly generated samples. Finally, plot these coordinates and its "origin" on the same set of axes to see your function in action. Explore with different values for your inputs.

# %%
def neighbourhood(c, r, n, s):
    V = []
    fig, ax = plt.subplots()
    ax.grid()
    for i in range(n):
        x = np.random.uniform(low =-10, high = 10)
        y = np.random.uniform(low =-10, high = 10)
    
        if s == 1:
            if sqrt((c[0]-x)**2 + (c[1]-y)**2) <= r:
                V.append((x,y))
                ax.plot(x,y,'bo')
            
        if s == 2:
            if abs(c[0] - x) + abs(c[1] - y) <= r:
                V.append((x,y))
                ax.plot(x,y,'bo')
    
    ax.plot(c[0],c[1],'ro')
    return V

               
    raise NotImplementedError()

# %%
# Question 1 is ungraded. You see run the below code to see if your code correctly generates the neigbourhoods
c = [np.random.randint(10), np.random.randint(10)]
r = 5
n = 1000 
s = 2

neighbourhood(c, r, n, s)
# Out:
# /usr/local/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# [(2.5267414605391103, 6.993763816631297),
#  (2.9980837984893753, 0.2071491719186085),
#  (6.700847420042443, 3.819893202995292),
#  (3.217178597686871, 7.062549070232336),
#  (4.732680060871248, 1.6962560443122658),
#  (0.5163373941062623, 3.4147804008861655),
#  (1.8677886551377902, 5.5625706561278125),
#  (-0.7157948812296802, 3.4437582926479493),
#  (0.6737795470863617, 4.543096791131699),
#  (0.5101238594925519, 3.043885007423615),
#  (3.7901758928523464, 4.895392011093168),
#  (5.00590227845853, 1.1275326184132126),
#  (1.1223530299615092, 5.953877853831624),
#  (6.4798994849432034, 3.1370722790812167),
#  (0.9881718013517098, 4.804212589687353),
#  (0.4197019385058596, 5.084577933514051),
#  (3.065813361189008, 2.3608142162895227),
#  (2.98148610275671, 1.2186424557666324),
#  (2.1909231058194045, 7.270176943005286),
#  (3.871092333521389, 5.465822240508162),
#  (1.7060618589637517, 2.626962515075606),
#  (3.596562871211283, 0.7160744608171647),
#  (-0.17846432819136027, 3.5425367844581395),
#  (3.7933106741921563, 0.37521294064841904),
#  (2.553277906759483, 5.200257706792108),
#  (3.1023458429524293, 7.474315673989121),
#  (7.17814823836925, 4.039384713441761),
#  (1.871585600826272, 6.082617876315005),
#  (5.632014056569529, 2.5621511308532856),
#  (4.469917456621852, 2.1941516342346272),
#  (2.962146726208836, 5.05601888419433),
#  (5.035676551326427, 6.897383371513477),
#  (3.9959991252045803, 0.015563746837909065),
#  (-1.7994248465323643, 3.9597216240504878),
#  (3.1615983914690116, 3.0556150290094735),
#  (1.777210804008833, 1.7736748685673476),
#  (3.3697405642822886, -0.4785909632199896),
#  (1.7122973622931692, 6.1250531586795915),
#  (1.9313210217830008, 5.861387035137394),
#  (0.41823647357986715, 4.3440019664810485),
#  (2.4708042609933916, 3.9847498299867112),
#  (5.647719555893065, 3.756490674127768),
#  (5.832528078323765, 5.303239221702647),
#  (-0.5619788509478276, 5.3784341315354585),
#  (1.4714813037891243, 2.6561644175352317),
#  (3.1771947787844024, -0.6370055947831403),
#  (0.7108405507742326, 1.6814511513085968),
#  (6.1418983121381245, 5.718454684877001),
#  (4.30976085631716, 0.5401028615224046),
#  (7.1496246854825, 3.442592638491824),
#  (0.47979274952010265, 2.9057646968657913),
#  (3.557950357263133, 0.5082785575125488),
#  (0.49702300464735316, 3.0344110916398233),
#  (3.1748978047288574, 2.0927136925042067),
#  (0.3368369980876924, 6.249136675011865),
#  (1.5804809754750782, 5.828916866278286),
#  (2.636676876911528, 0.31030917725770735),
#  (2.4948283484772187, 3.152587432739992),
#  (2.3550711762091385, 4.207944141235345),
#  (3.1918550637594265, 4.965671390622468),
#  (1.58100338177697, 7.028967068579103),
#  (0.9439037346508528, 1.3781099100266623),
#  (0.7506286586314843, 5.233952028775729),
#  (2.0833773581685016, 3.7215727615016156),
#  (3.4506495058091957, 4.890519809793805),
#  (5.125966024428228, 6.66247023741138),
#  (3.387525958001694, 0.3861650245333603),
#  (3.257498120634473, 4.089244924622843),
#  (3.8009325115904407, 6.989905566373437),
#  (3.379721804936942, 1.9620106903776957),
#  (0.41207355843922144, 2.1375711632901577),
#  (2.4014822324799994, 4.3134351940195526),
#  (0.0868819059772008, 2.5979390934210613),
#  (3.9308425038149526, 4.750538500360793),
#  (4.00662911037093, 3.3859441045694894),
#  (2.217607061581825, 7.348598728807978),
#  (2.9897962199000254, 6.500089125111504),
#  (1.5092417519195305, 0.8783064224353048),
#  (2.72634554675761, 6.9332268258120955),
#  (1.1371301094638593, 4.593096816000632),
#  (2.83771236681606, 8.39949606720731),
#  (2.210609426636566, 4.1003238443813),
#  (6.23508271890401, 5.6120219706964924),
#  (3.926920090153473, 1.7671175030506152),
#  (6.220360772693976, 5.639896840294234),
#  (3.239059979548294, 8.649926436889771),
#  (0.6679692798433994, 2.1322465103431902),
#  (2.3656016789140466, 3.823912858037307),
#  (4.998411470489279, 3.420465519989529),
#  (2.1926546424557714, 3.89254333359691),
#  (5.2781369325834895, 4.560788438453759),
#  (2.696398387297128, 1.0204779781593238),
#  (-0.7288567606529455, 4.651847751917922),
#  (5.181605483042402, 3.7179277688523253),
#  (1.4269078262467545, 1.3220295552124242),
#  (5.976549410017791, 3.5451033688831686),
#  (0.8915069487003002, 4.148575506055083),
#  (1.2221515984826237, 6.739957023668833),
#  (1.674091398408951, 7.319414963150411),
#  (-1.53195240211363, 4.219502324615696),
#  (4.399298916490713, 1.283388666222912),
#  (2.3811586870214168, 8.263174699755833),
#  (3.6844826334045457, 2.478621161831825),
#  (3.9784099816445355, 6.871434955435831),
#  (3.5007289570582714, 1.2014241223489002),
#  (2.0515847769192934, 4.843657901824622),
#  (0.5364537075453768, 5.956216887440807),
#  (2.7557629299838347, 4.086343882756843),
#  (3.3646491957412685, 8.481319334380238),
#  (5.903691722333818, 3.222146654401497),
#  (0.7174051828679406, 4.786534576981531),
#  (3.761206894718054, 7.869729339350517),
#  (3.367954586195461, 2.339776072649551),
#  (2.63506613727861, 3.2084708112649363)]

# %% [markdown]
# ### Question 2
#
# Write a function which takes in as input an unordered vector of values. Your function should return a row vector ($1 \times 3$) containing the minimum value, median value and maximum value (in this order). Do not use the builtin sort function. Look up sorting algorithms, *bubble sort* for example.

# %%
def lst_arrange(x):
    """
    Inputs:
        x: an array of random integers
    
    Output:
        vals: an array of 3 elements, in the order of min, median and max values of the input
    """
    # YOUR CODE HERE
    arr = [0,0,0]
    for i in range(len(x)):
        for j in range(i+1, len(x)):
            if x[i] > x[j]:
                temp = x[i]
                x[i]=x[j]
                x[j]=temp
    mini=x[0]
    medi=x[(len(x)-1)//2]
    maxi=x[len(x)-1]
    arr[0],arr[1],arr[2]=mini,medi,maxi
    return arr
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell
y = np.random.randint(1, 10, 5)
nt.assert_array_almost_equal([np.min(y), np.median(y), np.max(y)], lst_arrange(y), err_msg= 'incorrect function')
print('All Tests Passed!!!')
# Out:
# All Tests Passed!!!

# %% [markdown]
# ### Question 3
#
# Write a function which takes as input an array of points, i.e. $[(x_1, y_1), (x_2, y_2), \ldots]$. It should return as output, a smaller array containing the points of the Convex Hull vertices (ensure no duplicates). Finally, plot this Convex Hull and the original set of points on the same axes to determine if your function is doing as instructed. Some algorithms which can find the convex hull are *Andrew's monotone chain algorithm* and *gift wrapping*, there are others - choose whichever one you like.

# %%
def convex_hull(points):
    """
    Input: 
        points: an array of coordinates, i.e. [(x1, y1), (x2, y2), (x3, y3), ....]
    Output: 
        lst: a smaller array of coordinates, now only contain vertices of the hull with no duplicates
    """
    points = sorted(set(points))

    if len(points) <= 1:
        return points


    def cross(o, a, b):
        return (a[0] - o[0]) * (b[1] - o[1]) - (a[1] - o[1]) * (b[0] - o[0])

    
    lower = []
    for p in points:
        while len(lower) >= 2 and cross(lower[-2], lower[-1], p) <= 0:
            lower.pop()
        lower.append(p)

  
    upper = []
    for p in reversed(points):
        while len(upper) >= 2 and cross(upper[-2], upper[-1], p) <= 0:
            upper.pop()
        upper.append(p)
 
    return lower[:-1] + upper[:-1]
    raise NotImplementedError()

# %%
# Run this test cell to check your code
# Do not delete this cell

assert sorted(convex_hull([(i//10, i%10) for i in range(100)])) == sorted([(0, 0), (9, 0), (9, 9), (0, 9)])
assert sorted(convex_hull([(4, 82), (80, 43), (74, 67), (77, 83), (60, 41), (4, 6), (38, 23), 
                    (4, 19), (92, 70), (62, 74), (84, 30), (63, 22), (37, 45), (56, 81), 
                    (31, 19), (31, 0), (91, 48), (34, 22), (58, 72), (22, 78), (78, 28), 
                    (15, 15), (49, 89), (13, 39), (11, 68), (18, 28), (49, 61), (11, 35), 
                    (15, 6), (61, 22), (63, 82), (31, 39), (1, 50), (50, 74), (77, 67), 
                    (58, 83), (46, 42), (62, 24), (66, 39), (93, 11), (0, 47), (29, 94), 
                    (2, 60), (43, 83), (67, 97), (32, 59), (97, 73), (43, 72), (33, 85), 
                    (48, 87), (41, 48), (95, 0), (98, 28), (17, 70), (55, 26), (7, 23), 
                    (60, 31), (79, 89), (47, 2), (43, 34), (94, 84), (12, 92), (47, 69), 
                    (25, 67), (95, 90), (16, 31), (5, 58), (84, 71), (15, 6), (23, 12), 
                    (57, 48), (36, 59), (84, 61), (95, 18), (16, 66), (84, 94), (2, 5), 
                    (9, 5), (97, 77), (0, 58), (37, 17), (25, 70), (51, 42), (78, 63), 
                    (42, 70), (31, 63), (93, 9), (33, 10), (2, 46), (66, 68), (74, 57), 
                    (69, 93), (86, 76), (78, 73), (55, 22), (68, 41), (69, 43), (97, 5), 
                    (95, 22), (27, 89)])) == sorted([(0, 47), (2, 5), (31, 0), (95, 0), (97, 5), 
                                             (98, 28), (97, 77), (95, 90), (84, 94), (67, 97), 
                                             (29, 94), (12, 92), (4, 82), (0, 58)])
print('All Tests Passed!!!')
# Out:
# All Tests Passed!!!

# %%
# To plot and see if you convex hull looks correct. This is just a sanity check
# You should be aiming to see all the points plotted in blue dots and the convex
# hull wrapping the points in red.

lst = []
n   = 100
for i in range(100):
    lst.append((np.random.randint(100), np.random.randint(100)))
    
plt.figure()
for x in lst:
    plt.plot(x[0], x[1], 'bo')
    
lst2 = convex_hull(lst)
nn   = len(lst2)

xx = [lst2[i][0] for i in list(range(nn))]
xx.append(lst2[0][0])

yy = [lst2[i][1] for i in list(range(nn))]
yy.append(lst2[0][1])
plt.plot(xx, yy, 'r-')
